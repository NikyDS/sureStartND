# %% [markdown]
# <a href="https://colab.research.google.com/github/NikyDS/sureStartND/blob/main/Day21Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 17s 13ms/step - loss: 0.3841 - val_loss: 0.1907
# Epoch 2/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1807 - val_loss: 0.1528
# Epoch 3/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1485 - val_loss: 0.1335
# Epoch 4/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1319 - val_loss: 0.1217
# Epoch 5/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1208 - val_loss: 0.1135
# Epoch 6/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1131 - val_loss: 0.1076
# Epoch 7/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1076 - val_loss: 0.1031
# Epoch 8/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1034 - val_loss: 0.0998
# Epoch 9/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1005 - val_loss: 0.0974
# Epoch 10/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0981 - val_loss: 0.0956
# Epoch 11/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0965 - val_loss: 0.0946
# Epoch 12/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0955 - val_loss: 0.0938
# Epoch 13/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0951 - val_loss: 0.0934
# Epoch 14/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0946 - val_loss: 0.0932
# Epoch 15/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0942 - val_loss: 0.0927
# Epoch 16/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0939 - val_loss: 0.0925
# Epoch 17/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0936 - val_loss: 0.0924
# Epoch 18/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0937 - val_loss: 0.0923
# Epoch 19/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0935 - val_loss: 0.0925
# Epoch 20/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0935 - val_loss: 0.0920
# Epoch 21/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 22/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 23/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0932 - val_loss: 0.0919
# Epoch 24/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 25/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0933 - val_loss: 0.0918
# Epoch 26/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 27/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 28/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 29/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 30/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 31/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 32/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 33/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 34/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 35/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 36/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 37/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0925 - val_loss: 0.0916
# Epoch 38/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0925 - val_loss: 0.0916
# Epoch 39/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 40/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 41/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 42/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 43/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0928 - val_loss: 0.0915
# Epoch 44/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 45/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0928 - val_loss: 0.0915
# Epoch 46/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 47/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0925 - val_loss: 0.0915
# Epoch 48/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 49/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 50/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0927 - val_loss: 0.0915

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from keras import regularizers

encoding_dim = 32

input_img = keras.Input(shape=(784,))
# Add a Dense layer with a L1 activity regularizer
encoded = layers.Dense(encoding_dim, activation='relu',
                activity_regularizer=regularizers.l1(10e-5))(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

# %%
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 5s 17ms/step - loss: 0.3382 - val_loss: 0.1624
# Epoch 2/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1539 - val_loss: 0.1313
# Epoch 3/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1295 - val_loss: 0.1202
# Epoch 4/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1201 - val_loss: 0.1135
# Epoch 5/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1137 - val_loss: 0.1095
# Epoch 6/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1094 - val_loss: 0.1061
# Epoch 7/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1065 - val_loss: 0.1036
# Epoch 8/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1039 - val_loss: 0.1009
# Epoch 9/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1014 - val_loss: 0.0991
# Epoch 10/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0995 - val_loss: 0.0975
# Epoch 11/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0981 - val_loss: 0.0959
# Epoch 12/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0966 - val_loss: 0.0952
# Epoch 13/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0959 - val_loss: 0.0943
# Epoch 14/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0949 - val_loss: 0.0936
# Epoch 15/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0940 - val_loss: 0.0929
# Epoch 16/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0936 - val_loss: 0.0921
# Epoch 17/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0927 - val_loss: 0.0920
# Epoch 18/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0922 - val_loss: 0.0911
# Epoch 19/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0916 - val_loss: 0.0906
# Epoch 20/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0911 - val_loss: 0.0901
# Epoch 21/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0907 - val_loss: 0.0901
# Epoch 22/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0903 - val_loss: 0.0897
# Epoch 23/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0899 - val_loss: 0.0891
# Epoch 24/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0893 - val_loss: 0.0886
# Epoch 25/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0889 - val_loss: 0.0881
# Epoch 26/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0884 - val_loss: 0.0873
# Epoch 27/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0879 - val_loss: 0.0874
# Epoch 28/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0876 - val_loss: 0.0865
# Epoch 29/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0871 - val_loss: 0.0863
# Epoch 30/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0868 - val_loss: 0.0860
# Epoch 31/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0863 - val_loss: 0.0857
# Epoch 32/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0859 - val_loss: 0.0853
# Epoch 33/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0856 - val_loss: 0.0848
# Epoch 34/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0850 - val_loss: 0.0846
# Epoch 35/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0849 - val_loss: 0.0843
# Epoch 36/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0847 - val_loss: 0.0844
# Epoch 37/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0842 - val_loss: 0.0841
# Epoch 38/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0842 - val_loss: 0.0837
# Epoch 39/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0841 - val_loss: 0.0836
# Epoch 40/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0837 - val_loss: 0.0834
# Epoch 41/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0835 - val_loss: 0.0830
# Epoch 42/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0832 - val_loss: 0.0829
# Epoch 43/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0832 - val_loss: 0.0825
# Epoch 44/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0830 - val_loss: 0.0826
# Epoch 45/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0829 - val_loss: 0.0823
# Epoch 46/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0823 - val_loss: 0.0820
# Epoch 47/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0824 - val_loss: 0.0819
# Epoch 48/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0824 - val_loss: 0.0819
# Epoch 49/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0824 - val_loss: 0.0818
# Epoch 50/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0819 - val_loss: 0.0815
# Epoch 51/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0817 - val_loss: 0.0814
# Epoch 52/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0819 - val_loss: 0.0812
# Epoch 53/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0816 - val_loss: 0.0813
# Epoch 54/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0815 - val_loss: 0.0812
# Epoch 55/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0815 - val_loss: 0.0812
# Epoch 56/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0813 - val_loss: 0.0811
# Epoch 57/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0812 - val_loss: 0.0811
# Epoch 58/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0812 - val_loss: 0.0808
# Epoch 59/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0810 - val_loss: 0.0808
# Epoch 60/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0808 - val_loss: 0.0805
# Epoch 61/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0809 - val_loss: 0.0804
# Epoch 62/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0808 - val_loss: 0.0806
# Epoch 63/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0808 - val_loss: 0.0804
# Epoch 64/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0805 - val_loss: 0.0802
# Epoch 65/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0805 - val_loss: 0.0802
# Epoch 66/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0804 - val_loss: 0.0803
# Epoch 67/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0803 - val_loss: 0.0800
# Epoch 68/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0801 - val_loss: 0.0800
# Epoch 69/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0802 - val_loss: 0.0799
# Epoch 70/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0803 - val_loss: 0.0800
# Epoch 71/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0801 - val_loss: 0.0799
# Epoch 72/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0801 - val_loss: 0.0798
# Epoch 73/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0798 - val_loss: 0.0799
# Epoch 74/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0799 - val_loss: 0.0797
# Epoch 75/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0797 - val_loss: 0.0796
# Epoch 76/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 77/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0798 - val_loss: 0.0796
# Epoch 78/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0796 - val_loss: 0.0795
# Epoch 79/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0795 - val_loss: 0.0794
# Epoch 80/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0795 - val_loss: 0.0799
# Epoch 81/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0797 - val_loss: 0.0794
# Epoch 82/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0794 - val_loss: 0.0793
# Epoch 83/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0792 - val_loss: 0.0792
# Epoch 84/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0795 - val_loss: 0.0793
# Epoch 85/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0793 - val_loss: 0.0792
# Epoch 86/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0793 - val_loss: 0.0793
# Epoch 87/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0792 - val_loss: 0.0792
# Epoch 88/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0792 - val_loss: 0.0791
# Epoch 89/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0790 - val_loss: 0.0792
# Epoch 90/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0791 - val_loss: 0.0788
# Epoch 91/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0790 - val_loss: 0.0790
# Epoch 92/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0791 - val_loss: 0.0790
# Epoch 93/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0792 - val_loss: 0.0789
# Epoch 94/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0790 - val_loss: 0.0790
# Epoch 95/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0791 - val_loss: 0.0789
# Epoch 96/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0790 - val_loss: 0.0788
# Epoch 97/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0791 - val_loss: 0.0789
# Epoch 98/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 99/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 100/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0788 - val_loss: 0.0788

# %%
import keras
from keras import layers

input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
#tensorboard --logdir=/tmp/autoencoder

# %%
from keras.callbacks import TensorBoard

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 72s 148ms/step - loss: 0.3182 - val_loss: 0.1499
# Epoch 2/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1440 - val_loss: 0.1288
# Epoch 3/50
# 469/469 [==============================] - 69s 146ms/step - loss: 0.1278 - val_loss: 0.1208
# Epoch 4/50
# 469/469 [==============================] - 69s 146ms/step - loss: 0.1204 - val_loss: 0.1159
# Epoch 5/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1164 - val_loss: 0.1125
# Epoch 6/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1132 - val_loss: 0.1102
# Epoch 7/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1112 - val_loss: 0.1084
# Epoch 8/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1096 - val_loss: 0.1068
# Epoch 9/50
# 469/469 [==============================] - 71s 152ms/step - loss: 0.1081 - val_loss: 0.1054
# Epoch 10/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1066 - val_loss: 0.1042
# Epoch 11/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1053 - val_loss: 0.1033
# Epoch 12/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1044 - val_loss: 0.1038
# Epoch 13/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1034 - val_loss: 0.1019
# Epoch 14/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1031 - val_loss: 0.1010
# Epoch 15/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1021 - val_loss: 0.1007
# Epoch 16/50
# 469/469 [==============================] - 70s 149ms/step - loss: 0.1018 - val_loss: 0.1008
# Epoch 17/50
# 469/469 [==============================] - 71s 152ms/step - loss: 0.1014 - val_loss: 0.1008
# Epoch 18/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.1008 - val_loss: 0.0994
# Epoch 19/50
# 469/469 [==============================] - 71s 152ms/step - loss: 0.1004 - val_loss: 0.0987
# Epoch 20/50
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0999 - val_loss: 0.0989
# Epoch 21/50
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0995 - val_loss: 0.0983
# Epoch 22/50
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0994 - val_loss: 0.0977
# Epoch 23/50
# 469/469 [==============================] - 71s 152ms/step - loss: 0.0990 - val_loss: 0.0977
# Epoch 24/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.0986 - val_loss: 0.0980
# Epoch 25/50
# 469/469 [==============================] - 71s 152ms/step - loss: 0.0982 - val_loss: 0.0970
# Epoch 26/50
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0982 - val_loss: 0.0967
# Epoch 27/50
# 469/469 [==============================] - 71s 152ms/step - loss: 0.0978 - val_loss: 0.0962
# Epoch 28/50
# 469/469 [==============================] - 69s 147ms/step - loss: 0.0977 - val_loss: 0.0963
# Epoch 29/50
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0973 - val_loss: 0.0957
# Epoch 30/50
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0969 - val_loss: 0.0954
# Epoch 31/50
# 469/469 [==============================] - 70s 148ms/step - loss: 0.0965 - val_loss: 0.0954
# Epoch 32/50
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0963 - val_loss: 0.0950
# Epoch 33/50
# 469/469 [==============================] - 70s 148ms/step - loss: 0.0964 - val_loss: 0.0947
# Epoch 34/50
# 469/469 [==============================] - 70s 148ms/step - loss: 0.0959 - val_loss: 0.0956
# Epoch 35/50
# 469/469 [==============================] - 70s 150ms/step - loss: 0.0957 - val_loss: 0.0945
# Epoch 36/50
# 469/469 [==============================] - 70s 149ms/step - loss: 0.0956 - val_loss: 0.0941
# Epoch 37/50
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0954 - val_loss: 0.0948
# Epoch 38/50
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0952 - val_loss: 0.0944
# Epoch 39/50
# 469/469 [==============================] - 70s 149ms/step - loss: 0.0951 - val_loss: 0.0940
# Epoch 40/50
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0949 - val_loss: 0.0935
# Epoch 41/50
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0948 - val_loss: 0.0936
# Epoch 42/50
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0945 - val_loss: 0.0935
# Epoch 43/50
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0946 - val_loss: 0.0934
# Epoch 44/50
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0943 - val_loss: 0.0933
# Epoch 45/50
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0942 - val_loss: 0.0932
# Epoch 46/50
# 469/469 [==============================] - 70s 148ms/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 47/50
# 469/469 [==============================] - 70s 148ms/step - loss: 0.0939 - val_loss: 0.0926
# Epoch 48/50
# 469/469 [==============================] - 72s 154ms/step - loss: 0.0940 - val_loss: 0.0925
# Epoch 49/50
# 469/469 [==============================] - 73s 155ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 50/50
# 469/469 [==============================] - 71s 150ms/step - loss: 0.0936 - val_loss: 0.0924

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
encoder = keras.Model(input_img, encoded)
encoded_imgs = encoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 8))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(encoded_imgs[i].reshape((4, 4 * 8)).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=10,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/10
# 469/469 [==============================] - 139s 294ms/step - loss: 0.2557 - val_loss: 0.1168
# Epoch 2/10
# 469/469 [==============================] - 138s 293ms/step - loss: 0.1148 - val_loss: 0.1094
# Epoch 3/10
# 469/469 [==============================] - 138s 294ms/step - loss: 0.1086 - val_loss: 0.1048
# Epoch 4/10
# 469/469 [==============================] - 137s 292ms/step - loss: 0.1051 - val_loss: 0.1028
# Epoch 5/10
# 469/469 [==============================] - 137s 293ms/step - loss: 0.1033 - val_loss: 0.1013
# Epoch 6/10
# 469/469 [==============================] - 137s 293ms/step - loss: 0.1019 - val_loss: 0.1005
# Epoch 7/10
# 469/469 [==============================] - 137s 293ms/step - loss: 0.1008 - val_loss: 0.0996
# Epoch 8/10
# 469/469 [==============================] - 138s 293ms/step - loss: 0.0997 - val_loss: 0.0991
# Epoch 9/10
# 469/469 [==============================] - 138s 295ms/step - loss: 0.0993 - val_loss: 0.0984
# Epoch 10/10
# 469/469 [==============================] - 138s 294ms/step - loss: 0.0986 - val_loss: 0.0976

# %%
timesteps = ...  # Length of your sequences
input_dim = ... 
latent_dim = ...

inputs = keras.Input(shape=(timesteps, input_dim))
encoded = layers.LSTM(latent_dim)(inputs)

decoded = layers.RepeatVector(timesteps)(encoded)
decoded = layers.LSTM(input_dim, return_sequences=True)(decoded)

sequence_autoencoder = keras.Model(inputs, decoded)
encoder = keras.Model(inputs, encoded)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-a9c4f6d1f727> in <module>()
#       4
#       5 #inputs = keras.Input(shape=(timesteps, input_dim))
# ----> 6 encoded = layers.LSTM(latent_dim)(inputs)
#       7
#       8 decoded = layers.RepeatVector(timesteps)(encoded)
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in __init__(self, units, activation, recurrent_activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, unit_forget_bias, kernel_regularizer, recurrent_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, return_sequences, return_state, go_backwards, stateful, time_major, unroll, **kwargs)
#    1111
#    1112     self.state_spec = [
# -> 1113         InputSpec(shape=(None, dim)) for dim in (self.units, self.units)
#    1114     ]
#    1115     self._could_use_gpu_kernel = (
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in <listcomp>(.0)
#    1111
#    1112     self.state_spec = [
# -> 1113         InputSpec(shape=(None, dim)) for dim in (self.units, self.units)
#    1114     ]
#    1115     self._could_use_gpu_kernel = (
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py in __init__(self, dtype, shape, ndim, max_ndim, min_ndim, axes, allow_last_axis_squeeze, name)
#      76                name=None):
#      77     self.dtype = tf.as_dtype(dtype).name if dtype is not None else None
# ---> 78     shape = tf.TensorShape(shape)
#      79     if shape.rank is None:
#      80       shape = None
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_shape.py in __init__(self, dims)
#     763     """
#     764     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 765       self._dims = [Dimension(d) for d in dims]
#     766     elif dims is None:
#     767       self._dims = None
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_shape.py in <listcomp>(.0)
#     763     """
#     764     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 765       self._dims = [Dimension(d) for d in dims]
#     766     elif dims is None:
#     767       self._dims = None
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_shape.py in __init__(self, value)
#     207             TypeError("Dimension value must be integer or None or have "
#     208                       "an __index__ method, got value '{0!r}' with type '{1!r}'"
# --> 209                       .format(value, type(value))), None)
#     210       if self._value < 0:
#     211         raise ValueError("Dimension %d must be >= 0" % self._value)
#
# /usr/local/lib/python3.7/dist-packages/six.py in raise_from(value, from_value)
#
# TypeError: Dimension value must be integer or None or have an __index__ method, got value 'Ellipsis' with type '<class 'ellipsis'>'

# %%
original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
from keras import backend as K

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=10,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 181.8080 - val_loss: 167.6547
# Epoch 2/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 164.4375 - val_loss: 162.8066
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 161.3431 - val_loss: 160.5425
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 159.3472 - val_loss: 158.8241
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 157.6719 - val_loss: 157.1381
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 156.2390 - val_loss: 155.9437
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 155.0737 - val_loss: 154.7484
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 154.1906 - val_loss: 154.1186
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 153.4588 - val_loss: 153.3861
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 152.8449 - val_loss: 152.8759

# %%
x_test_encoded = encoder.predict(x_test, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-17cf7039b7a8> in <module>()
# ----> 1 x_test_encoded = encoder.predict(x_test, batch_size=batch_size)
#       2 plt.figure(figsize=(6, 6))
#       3 plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
#       4 plt.colorbar()
#       5 plt.show()
#
# NameError: name 'batch_size' is not defined

# %%
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
